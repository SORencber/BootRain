# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
mrkt= pd.read_csv(url,sep='\t')

# %%
mrkt.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %%
# reassign the column with the cleaned prices
mrkt.item_price = prices

# delete the duplicates in item_name and quantity
chipo_filtered = mrkt.drop_duplicates(['item_name','quantity','choice_description'])

# chipo_filtered

# select only the products with quantity equals to 1
chipo_one_prod = chipo_filtered[chipo_filtered.quantity == 1]
chipo_one_prod

# chipo_one_prod[chipo_one_prod['item_price']>10].item_name.nunique()
# chipo_one_prod[chipo_one_prod['item_price']>10]



mrkt.query('price_per_item > 10').item_name.nunique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     180             if self.has_resolvers:
# --> 181                 return self.resolvers[key]
#     182
#
# ~\Anaconda3\lib\collections\__init__.py in __getitem__(self, key)
#     913                 pass
# --> 914         return self.__missing__(key)            # support subclasses that define __missing__
#     915
#
# ~\Anaconda3\lib\collections\__init__.py in __missing__(self, key)
#     905     def __missing__(self, key):
# --> 906         raise KeyError(key)
#     907
#
# KeyError: 'price_per_item'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     191                 # e.g., df[df > 0]
# --> 192                 return self.temps[key]
#     193             except KeyError:
#
# KeyError: 'price_per_item'
#
# During handling of the above exception, another exception occurred:
#
# UndefinedVariableError                    Traceback (most recent call last)
# <ipython-input-21-277b7b690d8c> in <module>
#      17
#      18
# ---> 19 mrkt.query('price_per_item > 10').item_name.nunique()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in query(self, expr, inplace, **kwargs)
#    2845         kwargs['level'] = kwargs.pop('level', 0) + 1
#    2846         kwargs['target'] = None
# -> 2847         res = self.eval(expr, **kwargs)
#    2848
#    2849         try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in eval(self, expr, inplace, **kwargs)
#    2960             kwargs['target'] = self
#    2961         kwargs['resolvers'] = kwargs.get('resolvers', ()) + tuple(resolvers)
# -> 2962         return _eval(expr, inplace=inplace, **kwargs)
#    2963
#    2964     def select_dtypes(self, include=None, exclude=None):
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\eval.py in eval(expr, parser, engine, truediv, local_dict, global_dict, resolvers, level, target, inplace)
#     289
#     290         parsed_expr = Expr(expr, engine=engine, parser=parser, env=env,
# --> 291                            truediv=truediv)
#     292
#     293         # construct the engine and evaluate the parsed expression
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in __init__(self, expr, engine, parser, env, truediv, level)
#     737         self.env.scope['truediv'] = truediv
#     738         self._visitor = _parsers[parser](self.env, self.engine, self.parser)
# --> 739         self.terms = self.parse()
#     740
#     741     @property
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in parse(self)
#     754     def parse(self):
#     755         """Parse an expression"""
# --> 756         return self._visitor.visit(self.expr)
#     757
#     758     @property
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     319         method = 'visit_' + node.__class__.__name__
#     320         visitor = getattr(self, method)
# --> 321         return visitor(node, **kwargs)
#     322
#     323     def visit_Module(self, node, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit_Module(self, node, **kwargs)
#     325             raise SyntaxError('only a single expression is allowed')
#     326         expr = node.body[0]
# --> 327         return self.visit(expr, **kwargs)
#     328
#     329     def visit_Expr(self, node, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     319         method = 'visit_' + node.__class__.__name__
#     320         visitor = getattr(self, method)
# --> 321         return visitor(node, **kwargs)
#     322
#     323     def visit_Module(self, node, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit_Expr(self, node, **kwargs)
#     328
#     329     def visit_Expr(self, node, **kwargs):
# --> 330         return self.visit(node.value, **kwargs)
#     331
#     332     def _rewrite_membership_op(self, node, left, right):
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     319         method = 'visit_' + node.__class__.__name__
#     320         visitor = getattr(self, method)
# --> 321         return visitor(node, **kwargs)
#     322
#     323     def visit_Module(self, node, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit_Compare(self, node, **kwargs)
#     654             op = self.translate_In(ops[0])
#     655             binop = ast.BinOp(op=op, left=node.left, right=comps[0])
# --> 656             return self.visit(binop)
#     657
#     658         # recursive case: we have a chained comparison, a CMP b CMP c, etc.
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     319         method = 'visit_' + node.__class__.__name__
#     320         visitor = getattr(self, method)
# --> 321         return visitor(node, **kwargs)
#     322
#     323     def visit_Module(self, node, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit_BinOp(self, node, **kwargs)
#     423
#     424     def visit_BinOp(self, node, **kwargs):
# --> 425         op, op_class, left, right = self._maybe_transform_eq_ne(node)
#     426         left, right = self._maybe_downcast_constants(left, right)
#     427         return self._maybe_evaluate_binop(op, op_class, left, right)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in _maybe_transform_eq_ne(self, node, left, right)
#     360     def _maybe_transform_eq_ne(self, node, left=None, right=None):
#     361         if left is None:
# --> 362             left = self.visit(node.left, side='left')
#     363         if right is None:
#     364             right = self.visit(node.right, side='right')
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit(self, node, **kwargs)
#     319         method = 'visit_' + node.__class__.__name__
#     320         visitor = getattr(self, method)
# --> 321         return visitor(node, **kwargs)
#     322
#     323     def visit_Module(self, node, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expr.py in visit_Name(self, node, **kwargs)
#     437
#     438     def visit_Name(self, node, **kwargs):
# --> 439         return self.term_type(node.id, self.env, **kwargs)
#     440
#     441     def visit_NameConstant(self, node, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\ops.py in __init__(self, name, env, side, encoding)
#      56         self.is_local = (tname.startswith(_LOCAL_TAG) or
#      57                          tname in _DEFAULT_GLOBALS)
# ---> 58         self._value = self._resolve_name()
#      59         self.encoding = encoding
#      60
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\ops.py in _resolve_name(self)
#      73
#      74     def _resolve_name(self):
# ---> 75         res = self.env.resolve(self.local_name, is_local=self.is_local)
#      76         self.update(res)
#      77
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\scope.py in resolve(self, key, is_local)
#     192                 return self.temps[key]
#     193             except KeyError:
# --> 194                 raise compu.ops.UndefinedVariableError(key, is_local)
#     195
#     196     def swapkey(self, old_key, new_key, new_value=None):
#
# UndefinedVariableError: name 'price_per_item' is not defined

# %%
mrkt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
# order_id              4622 non-null int64
# quantity              4622 non-null int64
# item_name             4622 non-null object
# choice_description    3376 non-null object
# item_price            4622 non-null object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB

# %%
mrkt.shape
# Out:
# (4622, 5)

# %%
mrkt.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
mrkt.columns[0]
# Out:
# 'order_id'

# %%
c=mrkt.groupby("item_name")
c=c.sum()
c
# Out:
#                                        order_id  quantity
# item_name
# 6 Pack Soft Drink                         52322        55
# Barbacoa Bowl                             53972        66
# Barbacoa Burrito                          74718        91
# Barbacoa Crispy Tacos                      5613        12
# Barbacoa Salad Bowl                        9708        10
# Barbacoa Soft Tacos                       18725        25
# Bottled Water                            175944       211
# Bowl                                        472         4
# Burrito                                    1550         6
# Canned Soda                               76396       126
# Canned Soft Drink                        304753       351
# Carnitas Bowl                             62742        71
# Carnitas Burrito                          51652        60
# Carnitas Crispy Tacos                      5868         8
# Carnitas Salad                             1500         1
# Carnitas Salad Bowl                        6693         6
# Carnitas Soft Tacos                       37673        40
# Chicken Bowl                             713926       761
# Chicken Burrito                          497303       591
# Chicken Crispy Tacos                      47382        50
# Chicken Salad                             10465         9
# Chicken Salad Bowl                       117104       123
# Chicken Soft Tacos                        98395       120
# Chips                                    208004       230
# Chips and Fresh Tomato Salsa             100419       130
# Chips and Guacamole                      449959       506
# Chips and Mild Fresh Tomato Salsa           279         1
# Chips and Roasted Chili Corn Salsa        14999        23
# Chips and Roasted Chili-Corn Salsa        17462        18
# Chips and Tomatillo Green Chili Salsa     41170        45
# Chips and Tomatillo Red Chili Salsa       45556        50
# Chips and Tomatillo-Green Chili Salsa     21826        33
# Chips and Tomatillo-Red Chili Salsa       18344        25
# Crispy Tacos                                434         2
# Izze                                      10587        20
# Nantucket Nectar                          21814        29
# Salad                                      1150         2
# Side of Chips                             84769       110
# Steak Bowl                               193752       221
# Steak Burrito                            328437       386
# Steak Crispy Tacos                        35818        36
# Steak Salad                                2362         4
# Steak Salad Bowl                          29590        31
# Steak Soft Tacos                          50177        56
# Veggie Bowl                               72270        87
# Veggie Burrito                            80962        97
# Veggie Crispy Tacos                         668         1
# Veggie Salad                               7265         6
# Veggie Salad Bowl                         17303        18
# Veggie Soft Tacos                          5520         8

# %%
c = c.sort_values(['quantity'], ascending=False)
c.head(1)
# Out:
#               order_id  quantity
# item_name
# Chicken Bowl    713926       761

# %%
d = mrkt.groupby("item_name")

# %%
d=d.sum()

# %%
d=d.sort_values("quantity",ascending=False)

# %%
d.head(3)
# Out:
#                      order_id  quantity
# item_name
# Chicken Bowl           713926       761
# Chicken Burrito        497303       591
# Chips and Guacamole    449959       506

# %%
mrkt.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
c = mrkt.groupby('choice_description').sum()
c = c.sort_values(['quantity'], ascending=False)
c.head(10)
# Out:
#                                                     order_id  quantity
# choice_description
# [Diet Coke]                                           123455       159
# [Coke]                                                122752       143
# [Sprite]                                               80426        89
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     43088        49
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     36041        42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese...     37550        40
# [Lemonade]                                             31892        36
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice,...     24432        36
# [Coca Cola]                                            19282        32
# [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream,...     29614        30

# %%
dollarizer = lambda x: float(x[1:-1])
mrkt.item_price = mrkt.item_price.apply(dollarizer).sum()

# %%
mrkt.item_price.dtype
# Out:
# dtype('float64')

# %%
dollarizer = lambda x: float(x[1:-1])

# %%
mrkt.item_price.dtype
# Out:
# dtype('float64')

# %%
total=(mrkt.item_price* mrkt.quantity).sum()

# %%
total
# Out:
# 171534795.52000004

# %%
revenue = (mrkt['quantity']* mrkt['item_price']).sum()
revenue
# Out:
# 171534795.52000004

# %%
orders = mrkt.order_id.value_counts().count()

# %%
orders
# Out:
# 1834

# %%
mrkt['revenue'] = mrkt['quantity'] * mrkt['item_price']
order_grouped = mrkt.groupby(by=['order_id']).sum()
order_grouped.mean()['revenue']
# Out:
# 93530.4228571399

# %%
mrkt.groupby(by=['order_id']).sum().mean()['revenue']
# Out:
# 93530.4228571399

# %%
chipo_filtered = mrkt.drop_duplicates(['item_name','quantity','choice_description'])

# %%
chipo_one_prod = chipo_filtered[chipo_filtered.quantity == 1]
chipo_one_prod
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# 13           7         1                           Chicken Bowl
# 16           8         1                        Chicken Burrito
# 17           9         1                        Chicken Burrito
# 19          10         1                           Chicken Bowl
# 21          11         1                       Barbacoa Burrito
# 22          11         1                       Nantucket Nectar
# 23          12         1                        Chicken Burrito
# 24          12         1                                   Izze
# 26          13         1                           Chicken Bowl
# 27          14         1                       Carnitas Burrito
[Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    34500.16  34500.16
# 252   [Tomatillo Red Chili Salsa, [Rice, Cheese, Let...    34500.16  34500.16
# 257   [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]    34500.16  34500.16
# 284    [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream]]    34500.16  34500.16
# 290   [Roasted Chili Corn Salsa, [Fajita Vegetables,...    34500.16  34500.16
# 291   [Tomatillo Green Chili Salsa, [Rice, Sour Crea...    34500.16  34500.16
# ...                                                 ...         ...       ...
# 4443  [Tomatillo Green Chili Salsa, [Rice, Pinto Bea...    34500.16  34500.16
# 4444  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    34500.16  34500.16
# 4465  [Fresh Tomato Salsa, [Rice, Black Beans, Cheese]]    34500.16  34500.16
# 4481                         [Fresh Tomato Salsa, Rice]    34500.16  34500.16
# 4483  [Fresh Tomato Salsa, [Rice, Pinto Beans, Chees...    34500.16  34500.16
# 4484  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    34500.16  34500.16
# 4486  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    34500.16  34500.16
# 4488  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    34500.16  34500.16
# 4495  [Fresh Tomato Salsa, [Rice, Pinto Beans, Sour ...    34500.16  34500.16
# 4498  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...    34500.16  34500.16
# 4506  [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream...    34500.16  34500.16
# 4511  [Roasted Chili Corn Salsa, [Rice, Fajita Veget...    34500.16  34500.16
# 4532  [Roasted Chili Corn Salsa, [Rice, Black Beans,...    34500.16  34500.16
# 4537  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    34500.16  34500.16
# 4540  [Tomatillo Green Chili Salsa, [Fajita Vegetabl...    34500.16  34500.16
# 4553  [Roasted Chili Corn Salsa, [Black Beans, Sour ...    34500.16  34500.16
# 4555  [Roasted Chili Corn Salsa, [Fajita Vegetables,...    34500.16  34500.16
# 4564  [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    34500.16  34500.16
# 4574  [Roasted Chili Corn Salsa, [Rice, Cheese, Lett...    34500.16  34500.16
# 4576  [Fresh Tomato Salsa, [Rice, Cheese, Sour Cream...    34500.16  34500.16
# 4581  [Tomatillo Red Chili Salsa, [Rice, Black Beans...    34500.16  34500.16
# 4583  [Tomatillo Green Chili Salsa, [Rice, Black Bea...    34500.16  34500.16
# 4586  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    34500.16  34500.16
# 4587  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    34500.16  34500.16
# 4589  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    34500.16  34500.16
# 4590  [Roasted Chili Corn Salsa, [Rice, Black Beans,...    34500.16  34500.16
# 4591  [Tomatillo Red Chili Salsa, [Rice, Black Beans...    34500.16  34500.16
# 4595  [Tomatillo Green Chili Salsa, [Rice, Black Bea...    34500.16  34500.16
# 4599      [Roasted Chili Corn Salsa, [Cheese, Lettuce]]    34500.16  34500.16
# 4604  [Fresh Tomato Salsa, [Rice, Black Beans, Chees...    34500.16  34500.16
#
# [693 rows x 6 columns]

# %%
mrkt.item_name.sort_values()
mrkt.sort_values(by = "item_name")
chipo_drink_steak_bowl = mrkt[(mrkt.item_name == "Canned Soda") & (mrkt.quantity > 1)]
chipo_drink_steak_bowl.count()
# Out:
# order_id              20
# quantity              20
# item_name             20
# choice_description    20
# item_price            20
# revenue               20
# dtype: int64

# %%
mrkt.sort_values(by = "item_price", ascending = False).head(1)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
#
#    item_price   revenue
# 0    34500.16  34500.16

# %%
oc.tail(10)
# Out:
#      user_id  age gender     occupation zip_code
# 933      934   61      M       engineer    22902
# 934      935   42      M         doctor    66221
# 935      936   24      M          other    32789
# 936      937   48      M       educator    98072
# 937      938   38      F     technician    55038
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %%
oc.count()
# Out:
# user_id       943
# age           943
# gender        943
# occupation    943
# zip_code      943
# dtype: int64

# %%
oc.shape[1]
# Out:
# 5

# %%
oc.shape[0]
# Out:
# 943

# %%
oc.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
oc.index
# Out:
# RangeIndex(start=0, stop=943, step=1)

# %%
oc.columns.dtype
# Out:
# dtype('O')

# %%
oc.occupation
# Out:
# 0         technician
# 1              other
# 2             writer
# 3         technician
# 4              other
# 5          executive
# 6      administrator
# 7      administrator
# 8            student
# 9             lawyer
# 10             other
# 11             other
# 12          educator
# 13         scientist
# 14          educator
# 15     entertainment
# 16        programmer
# 17             other
# 18         librarian
# 19         homemaker
# 20            writer
# 21            writer
# 22            artist
# 23            artist
# 24          engineer
# 25          engineer
# 26         librarian
# 27            writer
# 28        programmer
# 29           student
#            ...
# 913            other
# 914    entertainment
# 915         engineer
# 916          student
# 917        scientist
# 918            other
# 919           artist
# 920          student
# 921    administrator
# 922          student
# 923            other
# 924         salesman
# 925    entertainment
# 926       programmer
# 927          student
# 928        scientist
# 929        scientist
# 930         educator
# 931         educator
# 932          student
# 933         engineer
# 934           doctor
# 935            other
# 936         educator
# 937       technician
# 938          student
# 939    administrator
# 940          student
# 941        librarian
# 942          student
# Name: occupation, Length: 943, dtype: object

# %%
a=oc.groupby(by='occupation').count()

# %%
a.sum()
# Out:
# user_id     943
# age         943
# gender      943
# zip_code    943
# dtype: int64

# %%
oc.groupby(by='occupation').count().max()
# Out:
# user_id     196
# age         196
# gender      196
# zip_code    196
# dtype: int64

# %%
oc.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-133-8b423cacd615> in <module>
# ----> 1 oc.summarize()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'summarize'

# %%
oc.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
oc.occupation.nunique()
# Out:
# 21

# %%
oc.occupation.value_counts().head(1)
# Out:
# student    196
# Name: occupation, dtype: int64

# %%
oc.describe()
# Out:
#           user_id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
oc.describe(include = "all")
# Out:
#            user_id         age gender occupation zip_code
# count   943.000000  943.000000    943        943      943
# unique         NaN         NaN      2         21      795
# top            NaN         NaN      M    student    55414
# freq           NaN         NaN    670        196        9
# mean    472.000000   34.051962    NaN        NaN      NaN
# std     272.364951   12.192740    NaN        NaN      NaN
# min       1.000000    7.000000    NaN        NaN      NaN
# 25%     236.500000   25.000000    NaN        NaN      NaN
# 50%     472.000000   31.000000    NaN        NaN      NaN
# 75%     707.500000   43.000000    NaN        NaN      NaN
# max     943.000000   73.000000    NaN        NaN      NaN

# %%
oc.occupation.nunique()
oc.occupation.value_counts().head(1).index[0]
# Out:
# 'student'

# %%
oc.age.value_counts().head()
# Out:
# 30    39
# 25    38
# 22    37
# 28    36
# 27    35
# Name: age, dtype: int64

# %%
round(oc.age.mean())
# Out:
# 34
