# %% [markdown]
# # Assignments for "Conditional Statements"

# %% [markdown]
# 1. Please get Celcius or Fahrenheit degrees from users and type a code to convert these heat units to each other.
#     For conversion, please use this formula: C = (5/9) * (F - 32)
#
#         Example : "40C" --> "104F"
#                   "52F" --> "11.1C"

# %%
Fahrenheit_i = int(input("Enter a temperature in Fahrenheit: "))
Celsius_i = int(input("Enter a temperature in Celsius: "))

if (Fahrenheit_i !=""):
    Celsius = (Fahrenheit_i - 32) * 5.0/9.0
    print(Fahrenheit_i,"F -->", Celsius,"F")
if(Celsius_i!=""):
    Fahrenheit = Celsius_i * 9.0/5.0 +32
    print(Celsius_i,"C -->", Fahrenheit,"F")
# Out:
# Enter a temperature in Fahrenheit: 12
# Enter a temperature in Celsius: 23
# 12 F --> -11.11111111111111 F
# 23 C --> 73.4 F

# %% [markdown]
# 2. A company decided to give a bonus of 5% to the employees if his/her year of service is more than 5 years.
# Ask the user for their salary and year of service and print the net bonus amount.

# %%
salary=int(input("Enter your salary:"))
your_exp=int(input("Enter year of your service :"))

if (your_exp>5):
  salary_bonus=salary*0.05
  print("Your bonus amount is ",salary_bonus)
else:
  print("There is no bonus for you. Pls too much work ")
# Out:
# Enter your salary:234
# Enter year of your service :6
# Your bonus amount is  11.700000000000001

# %% [markdown]
# 3. Take input of ages of 3 people by the user and determine the oldest and youngest among them.

# %%
ages=['0']
count=0
while True:
   if (count==3):
     ages.sort()
     print(ages)
     break
   else:
    count+=1
    age=input("Enter age:")
    ages.append(age)
# Out:
# Enter age:56
# Enter age:4
# Enter age:3
# ['0', '3', '4', '56']

# %% [markdown]
# 4. A student will not be allowed to attend to the exam if his / her attendance to classes is less than 75%. Take followings input from the user:
#     - Number of classes held,
#     - Number of classes attended.
#
#     Then, print the percentage of classes attended and whether the student is allowed to attend in an exam or not.

# %%
held=float(input("Number of classess held :"))
attend=float(input("Number of classes attended: "))
result=held*0.75
if (result<=attend):
  print("You are allowed to attend in the exam")
else:
  print("You are not allowed to attend in the exam "),
# Out:
# Number of classess held :10
# Number of classes attended: 8
# You are allowed to attend in the exam

# %% [markdown]
# 5. In this exercise, you will create a program that reads a letter of the alphabet from the user. According to the answer:
#
#     - If the user enters `a, e, i, o, u`, then your program should display a message indicating that the entered letter is a vowel.
#     - If the user enters `y`, then your program should display a message indicating that y is sometimes a vowel and sometimes a consonant.
#     - Otherwise, your program should display a message indicating that the letter is a consonant.

# %%
vowel=["a","e","i","o","u"]
enter=input("Enter a letter of the alphabet :")
if (enter in vowel):
    print("The letter is a vowel")
elif enter=="y":
    print("y is sometimes a vowel and sometimes a consonant")
else:
    print("the letter is a consonant")
# Out:
# Enter a letter of the alphabet :y
# y is sometimes a vowel and sometimes a consonant
