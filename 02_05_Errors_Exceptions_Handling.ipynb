# %% [markdown]
# # Assignments for "Errors and Exception Handling "

# %% [markdown]
# 1. Let us define a divisi
#
# ```
# # This is formatted as code
# ```
#
# on operation inside a function (using `def`) but to get an error, define the denominator as 0. So, type properly except statement.

# %%
def Division():
  try:
    a=1/0
    return a
  except Exception as e:
    print ("'{}' error occurred! ".format(e))

Division()
# Out:
# 'division by zero' error occurred!

# %% [markdown]
# 2. It is possible to get multiple errors after the execution of one try block. So, please define an error-exception issue with `NameError`.

# %%
def func():
  try:
    print(hello)
  except IOError:
    print('A problem occured reading a file.')
  except NameError:
    print('Name Error.')
func()
# Out:
# Name Error.

# %% [markdown]
# 3. Please define a function and with this function, generate a `ValueError` exception simply by entering a string instead of numerical value.

# %%
def func():
  try:
    numbers=int(input("Enter numbers"))
  
  except ValueError:
    print('Value Error.')
  else:
    print("Everything is OK")
func()
# Out:
# Enter numbersk
# Value Error.
